# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Data Science/Data Set/archive_3.zip')
df
# Out:
#                State            District                         Market  \
# 0     Andhra Pradesh             Chittor                       Chittoor
# 1     Andhra Pradesh             Chittor                       Chittoor
# 2     Andhra Pradesh             Chittor                       Chittoor
# 3     Andhra Pradesh            Cuddapah                       Cuddapah
# 4     Andhra Pradesh            Cuddapah                       Cuddapah
# ...              ...                 ...                            ...
# 5552     West Bengal  Sounth 24 Parganas  Diamond Harbour(South 24-pgs)
# 5553     West Bengal  Sounth 24 Parganas  Diamond Harbour(South 24-pgs)
# 5554     West Bengal      Uttar Dinajpur                       Islampur
# 5555     West Bengal      Uttar Dinajpur                       Islampur
# 5556     West Bengal      Uttar Dinajpur                       Islampur
#
#          Commodity     Variety   Grade  Min Price  Max Price  Modal Price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5557 entries, 0 to 5556
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        5557 non-null   object
#  1   District     5557 non-null   object
#  2   Market       5557 non-null   object
#  3   Commodity    5557 non-null   object
#  4   Variety      5557 non-null   object
#  5   Grade        5557 non-null   object
#  6   Min Price    5557 non-null   float64
#  7   Max Price    5557 non-null   float64
#  8   Modal Price  5557 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 390.9+ KB

# %%
df['State'].unique()
# Out:
# array(['Andhra Pradesh', 'Chandigarh', 'Chattisgarh', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Kerala',
#        'Madhya Pradesh', 'Meghalaya', 'Nagaland', 'NCT of Delhi',
#        'Odisha', 'Pondicherry', 'Punjab', 'Rajasthan', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttrakhand',
#        'West Bengal'], dtype=object)

# %%
df['State'].value_counts()
# Out:
# Uttar Pradesh        1944
# Kerala                791
# Punjab                472
# Gujarat               372
# Haryana               355
# Himachal Pradesh      254
# Telangana             187
# West Bengal           183
# Uttrakhand            176
# Odisha                168
# Rajasthan             140
# Tamil Nadu             99
# Tripura                87
# Madhya Pradesh         75
# Jammu and Kashmir      66
# Chattisgarh            56
# Nagaland               35
# NCT of Delhi           35
# Meghalaya              27
# Andhra Pradesh         17
# Chandigarh             14
# Goa                     3
# Pondicherry             1
# Name: State, dtype: int64

# %%
# Ploting the state column
sns.countplot(data=df, x='State')
plt.xlabel('State')
plt.ylabel('Values')
plt.title('States and its Values')
plt.xticks(rotation = 90)
plt.show()

# %%
df['District'].unique()
# Out:
# array(['Chittor', 'Cuddapah', 'East Godavari', 'Guntur', 'Kurnool',
#        'Visakhapatnam', 'Chandigarh', 'Balodabazar', 'Balrampur',
#        'Bastar', 'Bijapur', 'Bilaspur', 'Dantewada', 'Durg', 'Kanker',
#        'Koria', 'Mungeli', 'Narayanpur', 'Raigarh', 'Raipur', 'North Goa',
#        'Amreli', 'Anand', 'Banaskanth', 'Bharuch', 'Bhavnagar', 'Dahod',
#        'Gandhinagar', 'Jamnagar', 'Junagarh', 'Kheda', 'Morbi', 'Navsari',
#        'Patan', 'Rajkot', 'Sabarkantha', 'Surat', 'Surendranagar',
#        'Vadodara(Baroda)', 'Ambala', 'Faridabad', 'Fatehabad', 'Gurgaon',
#        'Hissar', 'Karnal', 'Kurukshetra', 'Mahendragarh-Narnaul', 'Mewat',
#        'Palwal', 'Panchkula', 'Panipat', 'Rewari', 'Rohtak', 'Sirsa',
#        'Sonipat', 'Yamuna Nagar', 'Chamba', 'Hamirpur', 'Kangra', 'Kullu',
#        'Sirmore', 'Una', 'Jammu', 'Srinagar', 'Udhampur', 'Alappuzha',
#        'Ernakulam', 'Idukki', 'Kannur', 'Kollam', 'Kottayam',
# ...

# %%
# Top ten district
df['District'].value_counts().head(10)
# Out:
# Palakad          162
# Kangra           138
# Bulandshahar     115
# Ernakulam        113
# Kollam            91
# Aligarh           81
# Alappuzha         81
# Muzaffarnagar     76
# Malappuram        75
# Jaunpur           71
# Name: District, dtype: int64

# %%
df.head()
# Out:
#             State  District    Market     Commodity   Variety   Grade  \
# 0  Andhra Pradesh   Chittor  Chittoor  Gur(Jaggery)      NO 2     FAQ
# 1  Andhra Pradesh   Chittor  Chittoor         Mango    Neelam  Medium
# 2  Andhra Pradesh   Chittor  Chittoor         Mango  Totapuri  Medium
# 3  Andhra Pradesh  Cuddapah  Cuddapah     Groundnut     Local     FAQ
# 4  Andhra Pradesh  Cuddapah  Cuddapah      Turmeric      Bulb     FAQ
#
#    Min Price  Max Price  Modal Price
# 0     3200.0     3400.0       3200.0
# 1      700.0     1500.0       1200.0
# 2     1400.0     1800.0       1600.0
# 3     4059.0     7589.0       7559.0
# 4     4778.0     6160.0       5845.0

# %%
df['Commodity'].value_counts()
# Out:
# Potato            286
# Onion             260
# Brinjal           240
# Tomato            225
# Green Chilli      213
#                  ...
# Lotus               1
# Orchid              1
# Patti Calcutta      1
# Raibel              1
# Jute                1
# Name: Commodity, Length: 186, dtype: int64

# %%
# Top ten commodity
df['Commodity'].value_counts().head(10)
# Out:
# Potato                   286
# Onion                    260
# Brinjal                  240
# Tomato                   225
# Green Chilli             213
# Bhindi(Ladies Finger)    212
# Bottle gourd             182
# Cucumbar(Kheera)         162
# Banana                   160
# Pumpkin                  157
# Name: Commodity, dtype: int64

# %%
sns.set(font_scale=0.5)
plt.figure(figsize=(20,10))
sns.countplot(data=df, x='Commodity')
plt.xlabel('Commodity')
plt.ylabel('Count')
plt.title('Count of Commodity')
plt.xticks(rotation = 90)
plt.show()

# %%
# Ploting which States has highest commodity price
sns.set(font_scale=1)
plt.figure(figsize=(20,10))
sns.barplot(data=df, x = 'State', y = 'Modal Price')
plt.xlabel('State')
plt.ylabel('Price')
plt.title('Price by State')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * Goa has highest commodity price as compair to other

# %%
# Ploting Boxplot 
sns.set(font_scale = 2)
plt.figure(figsize =(15,10))
sns.boxplot(data = df[['Min Price', 'Max Price', 'Modal Price']])
plt.show()

# %%
# Ploting Violin plot For Different Price
sns.set(font_scale = 2)
plt.figure(figsize = (15,10))
sns.violinplot(data = df[['Min Price', 'Max Price', 'Modal Price']])
plt.show()

# %%
sns.set(font_scale = 2)
plt.figure(figsize = (30,10))
sns.histplot(data = df[['Min Price', 'Max Price', 'Modal Price']], kde = True)
plt.show()

# %%
# ploting Scatter plot
sns.set(font_scale = 1)
plt.figure(figsize=(15,10))
sns.scatterplot(data = df, x = 'Min Price', y = 'Max Price')
plt.show()

# %%
# Finding Top ten Highest and lowest price by State
top_highest = df.nlargest(10, 'Modal Price')
top_lowest = df.nsmallest(10, 'Modal Price')

# %%
top_highest
# Out:
#              State       District                              Market  \
# 1354        Kerala         Idukki                          Kattappana
# 1357        Kerala         Idukki                          Kattappana
# 403        Gujarat  Surendranagar                              Halvad
# 284        Gujarat          Patan                                Sami
# 323        Gujarat         Rajkot                              Rajkot
# 2070  NCT of Delhi          Delhi  Fish,Poultry & Egg Market, Gazipur
# 262        Gujarat          Morbi                            Vankaner
# 304        Gujarat         Rajkot                              Jasdan
# 2081  NCT of Delhi          Delhi  Fish,Poultry & Egg Market, Gazipur
# 2849     Rajasthan        Jodhpur             Jodhpur (Grain)(Mandor)
#
#                Commodity             Variety Grade  Min Price  Max Price  \
# 1354           Cardamoms               Other   FAQ    95000.0   115000.0
# ...

# %%
# ploting Highest price by STATE
plt.figure(figsize = (15,10))
sns.barplot(data = top_highest, x = 'State', y = 'Modal Price')
plt.xlabel('State', fontweight ='bold', fontsize = 15)
plt.ylabel('Price', fontweight ='bold', fontsize = 15)
plt.title('Highest Price', fontweight ='bold', fontsize = 20)
plt.show()

# %%
top_lowest
# Out:
#              State District                 Market             Commodity  \
# 2099  NCT of Delhi    Delhi  Flower Market,Gazipur     Tube Rose(Single)
# 2098  NCT of Delhi    Delhi  Flower Market,Gazipur     Tube Rose(Double)
# 2097  NCT of Delhi    Delhi  Flower Market,Gazipur           Rose(Local)
# 2091  NCT of Delhi    Delhi  Flower Market,Gazipur               Jarbara
# 2088  NCT of Delhi    Delhi  Flower Market,Gazipur             Carnation
# 2089  NCT of Delhi    Delhi  Flower Market,Gazipur  Gladiolus Cut Flower
# 2093  NCT of Delhi    Delhi  Flower Market,Gazipur                 Lotus
# 2087  NCT of Delhi    Delhi  Flower Market,Gazipur                   BOP
# 2092  NCT of Delhi    Delhi  Flower Market,Gazipur                 Lilly
# 2094  NCT of Delhi    Delhi  Flower Market,Gazipur                Orchid
#
#                    Variety Grade  Min Price  Max Price  Modal Price
# 2099                 Other   FAQ       0.41       1.04         0.72
# ...

# %%
# Ploting the lowest State price
sns.barplot(data = top_lowest, x = 'State', y = 'Modal Price')
plt.xlabel('State', fontweight ='bold', fontsize = 15)
plt.ylabel('Price', fontweight ='bold', fontsize = 15)
plt.title('Lowest Price', fontweight ='bold', fontsize = 20)
plt.show()

# %% [markdown]
# # Ploting Top - Highest and Lowest By Market

# %%
plt.figure(figsize = (15,10))
plt.subplot(1, 2, 1)
sns.barplot(data = top_highest, x = 'Market', y = 'Modal Price')
plt.xlabel('Market', fontweight ='bold', fontsize = 15)
plt.ylabel('Price', fontweight ='bold', fontsize = 15)
plt.title('Top High Market Price', fontweight ='bold', fontsize = 20)
plt.xticks(rotation = 90)

plt.subplot(1, 2, 2)
sns.barplot(data = top_lowest, x = 'Market', y = 'Modal Price')
plt.xlabel('Market', fontweight ='bold', fontsize = 15)
plt.ylabel('Price', fontweight ='bold', fontsize = 15)
plt.title('Top Lowest Market price', fontweight ='bold', fontsize = 20)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Ploting Top - Higest and Lowest Commodity

# %%
plt.figure(figsize=(15,10))

plt.subplot(1, 2, 1)
plt.bar(top_highest['Commodity'], top_highest['Modal Price'])
plt.xlabel('Commodity', fontweight ='bold', fontsize = 15)
plt.ylabel('Price', fontweight ='bold', fontsize = 15)
plt.title('Top Commodity price',fontweight ='bold', fontsize = 20)

plt.subplot(1, 2, 2)
plt.bar(top_lowest['Commodity'], top_lowest['Modal Price'])
plt.xlabel('Commodity', fontweight ='bold', fontsize = 15)
plt.ylabel('Price', fontweight ='bold', fontsize = 15)
plt.title('Lowest Price', fontweight ='bold', fontsize = 20)
plt.xticks(rotation = 70)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Ploting Top - Highest and Lowest Variety Price

# %%
plt.figure(figsize = (15,10))

plt.subplot(1,2,1)
sns.barplot(data = top_highest, x = 'Variety', y = 'Modal Price', hue = 'Commodity')
plt.xlabel('Variety', fontweight ='bold', fontsize = 15)
plt.ylabel('Price', fontweight ='bold', fontsize = 15)
plt.title('Top Price of Variety', fontweight ='bold', fontsize = 20)
plt.xticks(rotation = 70)


plt.subplot(1,2,2)
sns.barplot(data = top_lowest, x = 'Variety', y = 'Modal Price', hue = 'Commodity')
plt.xlabel('Variety', fontweight ='bold', fontsize = 15)
plt.ylabel('Price', fontweight ='bold', fontsize = 15)
plt.title('Lowest Price of Variety', fontweight ='bold', fontsize = 20)
plt.xticks(rotation = 70)


plt.tight_layout()
plt.show()

# %%
sns.set(font_scale = 1)
sns.pairplot(data = df[['Min Price', 'Max Price', 'Modal Price']])
plt.show()

# %% [markdown]
# # Spliting train_test data

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
# Using onehotencoder for preprocessing
df = pd.get_dummies(df, columns = ['Grade'])
df
# Out:
#                State            District                         Market  \
# 0     Andhra Pradesh             Chittor                       Chittoor
# 1     Andhra Pradesh             Chittor                       Chittoor
# 2     Andhra Pradesh             Chittor                       Chittoor
# 3     Andhra Pradesh            Cuddapah                       Cuddapah
# 4     Andhra Pradesh            Cuddapah                       Cuddapah
# ...              ...                 ...                            ...
# 5552     West Bengal  Sounth 24 Parganas  Diamond Harbour(South 24-pgs)
# 5553     West Bengal  Sounth 24 Parganas  Diamond Harbour(South 24-pgs)
# 5554     West Bengal      Uttar Dinajpur                       Islampur
# 5555     West Bengal      Uttar Dinajpur                       Islampur
# 5556     West Bengal      Uttar Dinajpur                       Islampur
#
#          Commodity     Variety  Min Price  Max Price  Modal Price  Grade_FAQ  \
# ...

# %%
x = df[['Grade_FAQ', 'Grade_Large', 'Grade_Medium', 'Grade_Small', 'Min Price', 'Max Price']]
y = df['Modal Price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
x_train.shape, y_train.shape
# Out:
# ((4445, 6), (4445,))

# %%
x_test.shape, y_test.shape
# Out:
# ((1112, 6), (1112,))

# %%
x_train
# Out:
#       Grade_FAQ  Grade_Large  Grade_Medium  Grade_Small  Min Price  Max Price
# 1392          1            0             0            0     7500.0     7700.0
# 2633          1            0             0            0     1756.0     2245.0
# 2574          0            0             1            0     2500.0     3000.0
# 1255          1            0             0            0     2400.0     2600.0
# 4228          1            0             0            0     1100.0     1300.0
# ...         ...          ...           ...          ...        ...        ...
# 3772          1            0             0            0     2200.0     2280.0
# 5191          1            0             0            0     3150.0     3250.0
# 5226          1            0             0            0      400.0     1000.0
# 5390          1            0             0            0     5400.0     5600.0
# 860           0            0             1            0    15000.0    18000.0
#
# [4445 rows x 6 columns]

# %%
x_test
# Out:
#       Grade_FAQ  Grade_Large  Grade_Medium  Grade_Small  Min Price  Max Price
# 4962          1            0             0            0     1050.0     1330.0
# 4942          1            0             0            0      900.0     1200.0
# 4345          1            0             0            0     1440.0     1510.0
# 230           1            0             0            0     3000.0     3000.0
# 1044          0            0             1            0     2000.0     4500.0
# ...         ...          ...           ...          ...        ...        ...
# 4683          1            0             0            0     6375.0     6950.0
# 5381          1            0             0            0     1200.0     1500.0
# 2420          1            0             0            0     1800.0     2100.0
# 3631          1            0             0            0     2450.0     2500.0
# 70            1            0             0            0     1200.0     1400.0
#
# [1112 rows x 6 columns]

# %% [markdown]
# # Pridection of data

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# %%
# Linear_Regrassion_Model
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
linear_pred = linear_model.predict(x_test)

# %%
linear_pred
# Out:
# array([1187.44577721, 1047.5294273 , 1467.66262605, ..., 1950.49511727,
#        2470.41285747, 1295.62833183])

# %%
# Checking Score
linear_score = mean_squared_error(y_test, linear_pred)
linear_score
# Out:
# 16426.25884991981

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
linear_mape = mean_absolute_percentage_error(y_test, linear_pred, sample_weight = None, multioutput = 'uniform_average')
linear_mape
# Out:
# 0.04437125756631092

# %%
# DecisionTreeRegressor_model
decision_model = DecisionTreeRegressor()
decision_model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
decision_y = decision_model.predict(x_test)
decision_y
# Out:
# array([1300.        , 1026.66666667, 1470.        , ..., 1950.        ,
#        2460.        , 1300.        ])

# %%
# MSE
decision_mse = mean_squared_error(y_test, decision_y)
print('Score:', decision_mse)
# Out:
# Score: 283071.098908671

# %%
# MAPE
decision_mape = mean_absolute_percentage_error(y_test, decision_y, sample_weight = None, multioutput = 'uniform_average')
decision_mape
# Out:
# 8.208894750448023

# %% [markdown]
# # Conclusion
# ## Over Linear_model has good accuracy than DecisionTree

# %%
Score = {'Linear': [linear_mape], 'DecisionTree': [decision_mape]}
Score = pd.DataFrame(Score)
Score
# Out:
#      Linear  DecisionTree
# 0  0.044371      8.208895
